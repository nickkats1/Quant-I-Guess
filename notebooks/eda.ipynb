# %%
from src.config import load_config
from src.data_acquisition.download_data import LoadData
from src.financial_models.portfolio_optimization import EfficientDiversification
from src.financial_models.VaR import Var
from src.financial_models.sim import Sim


if __name__ == "__main__":
    config =load_config()
    
    # Load data config
    load_data_config = LoadData(config)
    
    # fetch all prices
    load_data_config.fetch_stock_data()
    
    # Value at Risk Config
    var_config = Var(config)
    var_config.load_data()
    # VaR and CVaR
    var_config.get_var()
    var_config.get_cvar()
    var_config.plot_returns()
    
    # Efficient Diversification config
    ef_config = EfficientDiversification(config)
    ef_config.fetch_data()
    ef_config.get_portfolio_returns()
    ef_config.portfolio_metrics()
    ef_config.weights
    ef_config.mu
    ef_config.S
    
    # single index model config
    sim_config = Sim(config)
    sim_config.get_data()
    # sp&500 data

    sim_config.get_market_data()
    sim_config.single_index_model()
# Out:
# /home/nickkats1/Quant-I-Guess/src/data_acquisition/download_data.py:27: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   self.stocks = yf.download(self.config['stock_tickers'],start=self.config['start_date'],end=self.config['end_date'])['Close']
# [*********************100%***********************]  10 of 10 completed
# /home/nickkats1/Quant-I-Guess/src/financial_models/VaR.py:21: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   self.data = yf.download(tickers=self.config["combined_assets"],start=self.config['start_date'],end=self.config['end_date'])['Close']
# [*********************100%***********************]  31 of 31 completed
#  Returns: Ticker          AAPL      ARKK   BNB-USD   BTC-USD       DIA       EFA  \
# Date
# 2020-12-24  0.007712 -0.014301  0.045106  0.021281  0.002456  0.000415
# 2020-12-28  0.035766 -0.024280  0.102889  0.141088  0.006556  0.008153
# 2020-12-29 -0.013315 -0.026895  0.086715  0.010250 -0.001776  0.006443
# 2020-12-30 -0.008526  0.022362 -0.020962  0.054034  0.002207  0.001362
# 2020-12-31 -0.007703 -0.020535 -0.019935  0.005574  0.005458 -0.007617
# ...              ...       ...       ...       ...       ...       ...
# 2025-10-08  0.006160  0.038380 -0.002759  0.015673  0.000215  0.002964
# 2025-10-09 -0.015578 -0.009402 -0.038810 -0.013370 -0.005514 -0.008232
# 2025-10-10 -0.034522 -0.056077 -0.118635 -0.069769 -0.018619 -0.018410
# 2025-10-13  0.009744  0.014448  0.168556  0.018167  0.012773  0.008023
# 2025-10-14  0.000444 -0.010368 -0.063722 -0.018673  0.004407  0.004517
#
# Ticker       ETH-USD         F        GM     GOOGL  ...      TSLA  USDC-USD  \
# Date                                                ...
# 2020-12-24  0.047785 -0.014460 -0.020495  0.003431  ...  0.024443  0.000135
# 2020-12-28  0.194226  0.003386  0.001924  0.022951  ...  0.002901  0.000027
# 2020-12-29  0.001537 -0.007874 -0.002160 -0.009132  ...  0.003466 -0.000123
# 2020-12-30  0.027475  0.004535  0.006495 -0.012237  ...  0.043229  0.000033
# 2020-12-31 -0.018381 -0.007901 -0.004780  0.009440  ...  0.015674 -0.000204
# ...              ...       ...       ...       ...  ...       ...       ...
# 2025-10-08  0.017186 -0.015101 -0.015019 -0.004639  ...  0.012930  0.000043
# 2025-10-09 -0.035008 -0.020443 -0.008511 -0.012632  ... -0.007180 -0.000051
# 2025-10-10 -0.120421 -0.007826 -0.010193 -0.020536  ... -0.050627  0.000206
# 2025-10-13  0.104725  0.011394  0.004878  0.032041  ...  0.054197  0.000051
# 2025-10-14 -0.028279  0.009532  0.027508  0.005325  ... -0.015279 -0.000030
#
# Ticker      USDT-USD       VOO       VTI       WMT       XLF       XLK  \
# Date
# 2020-12-24  0.000505  0.003996  0.001673  0.001955  0.001384  0.006630
# 2020-12-28 -0.001328  0.008698  0.006327  0.011986  0.004836  0.011312
# 2020-12-29 -0.000013 -0.002104 -0.004174 -0.006335 -0.003437 -0.004750
# 2020-12-30  0.001687  0.001347  0.002691 -0.000831  0.004484 -0.000539
# 2020-12-31  0.000323  0.005383  0.004594 -0.000208  0.012363  0.001463
# ...              ...       ...       ...       ...       ...       ...
# 2025-10-08 -0.000153  0.005803  0.006644 -0.003293 -0.004835  0.017537
# 2025-10-09  0.000175 -0.002699 -0.003466 -0.010982 -0.003551 -0.001686
# 2025-10-10  0.001263 -0.026884 -0.026795  0.000688 -0.021755 -0.040696
# 2025-10-13 -0.000741  0.015154  0.015942  0.002749  0.009586  0.024354
# 2025-10-14 -0.000466 -0.001411 -0.000306  0.049843  0.011014 -0.012834
#
# Ticker       XRP-USD     ^GSPC
# Date
# 2020-12-24  0.306328  0.003537
# 2020-12-28 -0.266003  0.008723
# 2020-12-29 -0.108873 -0.002227
# 2020-12-30 -0.041337  0.001342
# 2020-12-31  0.037851  0.006439
# ...              ...       ...
# 2025-10-08  0.008695  0.005828
# 2025-10-09 -0.026345 -0.002756
# 2025-10-10 -0.159118 -0.027112
# 2025-10-13  0.105106  0.015599
# 2025-10-14 -0.038688 -0.001564
#
# [1206 rows x 31 columns]
# Value at Risk: -0.04013021539021564
# Conditional Value at Risk: -0.07172%
# /home/nickkats1/Quant-I-Guess/src/financial_models/portfolio_optimization.py:20: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   self.all_prices = yf.download(tickers=self.config['combined_assets'],start=self.config['start_date'],end=self.config['end_date'])['Close']
# [*********************100%***********************]  31 of 31 completed
# /home/nickkats1/Quant-I-Guess/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Expected annual return: 12.0%
# Annual volatility: 6.1%
# Sharpe Ratio: 1.96
# Market Index Risk: 0.00011651315438035876
# Returns for: AAPL, 1       0.007712
# 2       0.035766
# 3      -0.013315
# 4      -0.008527
# 5      -0.007703
#           ...
# 1192   -0.008332
# 1193    0.018073
# 1194   -0.005489
# 1195   -0.004032
# 1196    0.000786
# Name: AAPL, Length: 1196, dtype: float64
# Excess Returns: 1      -0.001488
# 2       0.026566
# 3      -0.022515
# 4      -0.017727
# 5      -0.016903
#           ...
# 1192   -0.017532
# 1193    0.008873
# 1194   -0.014689
# 1195   -0.013232
# 1196   -0.008414
# Name: AAPL, Length: 1196, dtype: float64
# Market Returns: ^GSPC,1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64;----- Market Excess Returns: 1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64
# Alpha Value: 0.0000
# Beta Value: 1.2587
# Adjusted Beta: 1.172483
# Firm Specific Risk: 0.0001
# Systematic Risk: 0.0002
# Total Risk: 0.00031832431079010105
# Error Term: 1       0.003224
# 2       0.024750
# 3      -0.010548
# 4      -0.010252
# 5      -0.015844
#           ...
# 1192   -0.004786
# 1193    0.024341
# 1194   -0.012955
# 1195   -0.007386
# 1196   -0.004400
# Length: 1196, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   AAPL   R-squared:                       0.580
# Model:                            OLS   Adj. R-squared:                  0.580
# Method:                 Least Squares   F-statistic:                     1648.
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):          4.10e-227
# Time:                        18:53:07   Log-Likelihood:                 3637.0
# No. Observations:                1196   AIC:                            -7270.
# Df Residuals:                    1194   BIC:                            -7260.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.685e-05      0.000      0.110      0.912      -0.001       0.001
# ^GSPC          1.2587      0.031     40.599      0.000       1.198       1.320
# ==============================================================================
# Omnibus:                      109.739   Durbin-Watson:                   1.818
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              628.674
# Skew:                           0.169   Prob(JB):                    3.06e-137
# Kurtosis:                       6.536   Cond. No.                         92.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 57.99
# Expected Return: AAPL    0.156693
# dtype: float64
# Returns for: MSFT, 1       0.007827
# 2       0.009921
# 3      -0.003601
# 4      -0.011019
# 5       0.003338
#           ...
# 1192    0.001807
# 1193   -0.006116
# 1194    0.008737
# 1195    0.006139
# 1196    0.006510
# Name: MSFT, Length: 1196, dtype: float64
# Excess Returns: 1      -0.001373
# 2       0.000721
# 3      -0.012801
# 4      -0.020219
# 5      -0.005862
#           ...
# 1192   -0.007393
# 1193   -0.015316
# 1194   -0.000463
# 1195   -0.003061
# 1196   -0.002690
# Name: MSFT, Length: 1196, dtype: float64
# Market Returns: ^GSPC,1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64;----- Market Excess Returns: 1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64
# Alpha Value: 0.0002
# Beta Value: 1.1658
# Adjusted Beta: 1.110540
# Firm Specific Risk: 0.0001
# Systematic Risk: 0.0002
# Total Risk: 0.00026799588485270216
# Error Term: 1       0.003473
# 2      -0.000479
# 3      -0.001235
# 4      -0.012815
# 5      -0.004399
#           ...
# 1192    0.004894
# 1193   -0.000507
# 1194    0.001625
# 1195    0.002835
# 1196    0.001510
# Length: 1196, dtype: float64
# /home/nickkats1/Quant-I-Guess/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   MSFT   R-squared:                       0.591
# Model:                            OLS   Adj. R-squared:                  0.591
# Method:                 Least Squares   F-statistic:                     1724.
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):          5.62e-234
# Time:                        18:53:08   Log-Likelihood:                 3755.7
# No. Observations:                1196   AIC:                            -7507.
# Df Residuals:                    1194   BIC:                            -7497.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.000      0.762      0.446      -0.000       0.001
# ^GSPC          1.1658      0.028     41.527      0.000       1.111       1.221
# ==============================================================================
# Omnibus:                      219.082   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3641.457
# Skew:                           0.310   Prob(JB):                         0.00
# Kurtosis:                      11.526   Cond. No.                         92.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 59.09
# Expected Return: MSFT    0.206529
# dtype: float64
# Returns for: TGT, 1       0.001601
# 2       0.006850
# 3      -0.007654
# 4      -0.006627
# 5       0.015240
#           ...
# 1192    0.014474
# 1193   -0.013249
# 1194    0.008148
# 1195    0.011155
# 1196    0.009794
# Name: TGT, Length: 1196, dtype: float64
# Excess Returns: 1      -0.007599
# 2      -0.002350
# 3      -0.016854
# 4      -0.015827
# 5       0.006040
#           ...
# 1192    0.005274
# 1193   -0.022449
# 1194   -0.001052
# 1195    0.001955
# 1196    0.000594
# Name: TGT, Length: 1196, dtype: float64
# Market Returns: ^GSPC,1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64;----- Market Excess Returns: 1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64
# Alpha Value: -0.0007
# Beta Value: 0.9834
# Adjusted Beta: 0.988926
# Firm Specific Risk: 0.0004
# Systematic Risk: 0.0001
# Total Risk: 0.0004969861040159429
# Error Term: 1      -0.001134
# 2      -0.000984
# 3      -0.004720
# 4      -0.007203
# 5       0.009652
#           ...
# 1192    0.018017
# 1193   -0.007580
# 1194    0.003087
# 1195    0.009307
# 1196    0.006514
# Length: 1196, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    TGT   R-squared:                       0.227
# Model:                            OLS   Adj. R-squared:                  0.226
# Method:                 Least Squares   F-statistic:                     350.1
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):           1.05e-68
# Time:                        18:53:08   Log-Likelihood:                 3005.7
# No. Observations:                1196   AIC:                            -6007.
# Df Residuals:                    1194   BIC:                            -5997.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0007      0.001     -1.308      0.191      -0.002       0.000
# ^GSPC          0.9834      0.053     18.710      0.000       0.880       1.087
# ==============================================================================
# Omnibus:                      537.864   Durbin-Watson:                   1.991
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            50038.037
# Skew:                          -1.129   Prob(JB):                         0.00
# Kurtosis:                      34.607   Cond. No.                         92.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 22.67
# Expected Return: TGT   -0.107828
# dtype: float64
# /home/nickkats1/Quant-I-Guess/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for: GM, 1      -0.020495
# 2       0.001924
# 3      -0.002160
# 4       0.006495
# 5      -0.004780
#           ...
# 1192    0.022875
# 1193    0.011182
# 1194    0.010728
# 1195   -0.001960
# 1196   -0.002454
# Name: GM, Length: 1196, dtype: float64
# Excess Returns: 1      -0.029695
# 2      -0.007276
# 3      -0.011360
# 4      -0.002705
# 5      -0.013980
#           ...
# 1192    0.013675
# 1193    0.001982
# 1194    0.001528
# 1195   -0.011160
# 1196   -0.011654
# Name: GM, Length: 1196, dtype: float64
# Market Returns: ^GSPC,1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64;----- Market Excess Returns: 1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64
# Alpha Value: -0.0001
# Beta Value: 1.1925
# Adjusted Beta: 1.128339
# Firm Specific Risk: 0.0004
# Systematic Risk: 0.0002
# Total Risk: 0.0005456941260134911
# Error Term: 1      -0.024653
# 2      -0.008419
# 3       0.000555
# 4       0.004954
# 5      -0.012400
#           ...
# 1192    0.026328
# 1193    0.017214
# 1194    0.003749
# 1195   -0.005043
# 1196   -0.007274
# Length: 1196, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     GM   R-squared:                       0.304
# Model:                            OLS   Adj. R-squared:                  0.303
# Method:                 Least Squares   F-statistic:                     520.6
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):           6.25e-96
# Time:                        18:53:08   Log-Likelihood:                 3012.4
# No. Observations:                1196   AIC:                            -6021.
# Df Residuals:                    1194   BIC:                            -6011.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -5.9e-05      0.001     -0.104      0.917      -0.001       0.001
# ^GSPC          1.1925      0.052     22.817      0.000       1.090       1.295
# ==============================================================================
# Omnibus:                      111.959   Durbin-Watson:                   2.173
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              637.267
# Skew:                           0.193   Prob(JB):                    4.16e-139
# Kurtosis:                       6.555   Cond. No.                         92.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 30.36
# Expected Return: GM    0.086986
# dtype: float64
# /home/nickkats1/Quant-I-Guess/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for: F, 1      -0.014460
# 2       0.003386
# 3      -0.007874
# 4       0.004535
# 5      -0.007901
#           ...
# 1192   -0.008525
# 1193   -0.000860
# 1194    0.033563
# 1195    0.006661
# 1196   -0.010753
# Name: F, Length: 1196, dtype: float64
# Excess Returns: 1      -0.023660
# 2      -0.005814
# 3      -0.017074
# 4      -0.004665
# 5      -0.017101
#           ...
# 1192   -0.017725
# 1193   -0.010060
# 1194    0.024363
# 1195   -0.002539
# 1196   -0.019953
# Name: F, Length: 1196, dtype: float64
# Market Returns: ^GSPC,1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64;----- Market Excess Returns: 1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64
# Alpha Value: 0.0001
# Beta Value: 1.2411
# Adjusted Beta: 1.160725
# Firm Specific Risk: 0.0004
# Systematic Risk: 0.0002
# Total Risk: 0.0006221670001947642
# Error Term: 1      -0.018934
# 2      -0.007523
# 3      -0.005194
# 4       0.002786
# 5      -0.015976
#           ...
# 1192   -0.005076
# 1193    0.005273
# 1194    0.026154
# 1195    0.003306
# 1196   -0.015914
# Length: 1196, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      F   R-squared:                       0.288
# Model:                            OLS   Adj. R-squared:                  0.288
# Method:                 Least Squares   F-statistic:                     484.0
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):           2.50e-90
# Time:                        18:53:08   Log-Likelihood:                 2921.1
# No. Observations:                1196   AIC:                            -5838.
# Df Residuals:                    1194   BIC:                            -5828.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       8.396e-05      0.001      0.138      0.890      -0.001       0.001
# ^GSPC          1.2411      0.056     22.001      0.000       1.130       1.352
# ==============================================================================
# Omnibus:                      242.251   Durbin-Watson:                   2.061
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3300.176
# Skew:                          -0.519   Prob(JB):                         0.00
# Kurtosis:                      11.071   Cond. No.                         92.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 28.85
# Expected Return: F    0.122877
# dtype: float64
# /home/nickkats1/Quant-I-Guess/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for: WMT, 1       0.001955
# 2       0.011986
# 3      -0.006335
# 4      -0.000832
# 5      -0.000208
#           ...
# 1192    0.002048
# 1193    0.003115
# 1194    0.001067
# 1195   -0.000776
# 1196   -0.000194
# Name: WMT, Length: 1196, dtype: float64
# Excess Returns: 1      -0.007245
# 2       0.002786
# 3      -0.015535
# 4      -0.010032
# 5      -0.009408
#           ...
# 1192   -0.007152
# 1193   -0.006085
# 1194   -0.008133
# 1195   -0.009976
# 1196   -0.009394
# Name: WMT, Length: 1196, dtype: float64
# Market Returns: ^GSPC,1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64;----- Market Excess Returns: 1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64
# Alpha Value: 0.0005
# Beta Value: 0.4783
# Adjusted Beta: 0.652225
# Firm Specific Risk: 0.0001
# Systematic Risk: 0.0000
# Total Risk: 0.000170194331127987
# Error Term: 1      -0.000255
# 2       0.007295
# 3      -0.005788
# 4      -0.001992
# 5      -0.003807
#           ...
# 1192    0.002891
# 1193    0.004992
# 1194   -0.002274
# 1195   -0.002555
# 1196   -0.002670
# Length: 1196, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    WMT   R-squared:                       0.157
# Model:                            OLS   Adj. R-squared:                  0.156
# Method:                 Least Squares   F-statistic:                     221.8
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):           3.93e-46
# Time:                        18:53:08   Log-Likelihood:                 3594.6
# No. Observations:                1196   AIC:                            -7185.
# Df Residuals:                    1194   BIC:                            -7175.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.000      1.494      0.135      -0.000       0.001
# ^GSPC          0.4783      0.032     14.892      0.000       0.415       0.541
# ==============================================================================
# Omnibus:                      443.706   Durbin-Watson:                   1.975
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            12516.544
# Skew:                          -1.103   Prob(JB):                         0.00
# Kurtosis:                      18.694   Cond. No.                         92.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 15.66
# Expected Return: WMT    0.192478
# dtype: float64
# /home/nickkats1/Quant-I-Guess/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for: MCD, 1      -0.002971
# 2       0.012441
# 3      -0.006121
# 4      -0.005406
# 5       0.014275
#           ...
# 1192    0.003760
# 1193   -0.006670
# 1194    0.009725
# 1195   -0.007371
# 1196    0.002970
# Name: MCD, Length: 1196, dtype: float64
# Excess Returns: 1      -0.012171
# 2       0.003241
# 3      -0.015321
# 4      -0.014606
# 5       0.005075
#           ...
# 1192   -0.005440
# 1193   -0.015870
# 1194    0.000525
# 1195   -0.016571
# 1196   -0.006230
# Name: MCD, Length: 1196, dtype: float64
# Market Returns: ^GSPC,1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64;----- Market Excess Returns: 1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64
# Alpha Value: 0.0002
# Beta Value: 0.4289
# Adjusted Beta: 0.619290
# Firm Specific Risk: 0.0001
# Systematic Risk: 0.0000
# Total Risk: 0.00011707664485335095
# Error Term: 1      -0.004700
# 2       0.008488
# 3      -0.005377
# 4      -0.006194
# 5       0.011301
#           ...
# 1192    0.004769
# 1193   -0.004734
# 1194    0.006982
# 1195   -0.008714
# 1196    0.001004
# Length: 1196, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    MCD   R-squared:                       0.183
# Model:                            OLS   Adj. R-squared:                  0.182
# Method:                 Least Squares   F-statistic:                     267.6
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):           1.97e-54
# Time:                        18:53:09   Log-Likelihood:                 3837.4
# No. Observations:                1196   AIC:                            -7671.
# Df Residuals:                    1194   BIC:                            -7661.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.000      0.747      0.455      -0.000       0.001
# ^GSPC          0.4289      0.026     16.359      0.000       0.377       0.480
# ==============================================================================
# Omnibus:                       74.382   Durbin-Watson:                   2.019
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              272.807
# Skew:                           0.166   Prob(JB):                     5.77e-60
# Kurtosis:                       5.316   Cond. No.                         92.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 18.31
# Expected Return: MCD    0.103676
# dtype: float64
# /home/nickkats1/Quant-I-Guess/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for: SBUX, 1      -0.000490
# 2       0.022841
# 3       0.012364
# 4       0.003219
# 5       0.009531
#           ...
# 1192   -0.016571
# 1193   -0.005221
# 1194   -0.005249
# 1195    0.026982
# 1196   -0.012144
# Name: SBUX, Length: 1196, dtype: float64
# Excess Returns: 1      -0.009690
# 2       0.013641
# 3       0.003164
# 4      -0.005981
# 5       0.000331
#           ...
# 1192   -0.025771
# 1193   -0.014421
# 1194   -0.014449
# 1195    0.017782
# 1196   -0.021344
# Name: SBUX, Length: 1196, dtype: float64
# Market Returns: ^GSPC,1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64;----- Market Excess Returns: 1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64
# Alpha Value: -0.0004
# Beta Value: 1.0113
# Adjusted Beta: 1.007566
# Firm Specific Risk: 0.0003
# Systematic Risk: 0.0001
# Total Risk: 0.0003860252091064044
# Error Term: 1      -0.003627
# 2       0.014460
# 3       0.015056
# 4       0.002302
# 5       0.003459
#           ...
# 1192   -0.013252
# 1193    0.000285
# 1194   -0.010777
# 1195    0.024756
# 1196   -0.015841
# Length: 1196, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   SBUX   R-squared:                       0.309
# Model:                            OLS   Adj. R-squared:                  0.308
# Method:                 Least Squares   F-statistic:                     533.2
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):           7.80e-98
# Time:                        18:53:09   Log-Likelihood:                 3223.8
# No. Observations:                1196   AIC:                            -6444.
# Df Residuals:                    1194   BIC:                            -6433.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0004      0.000     -0.930      0.353      -0.001       0.000
# ^GSPC          1.0113      0.044     23.092      0.000       0.925       1.097
# ==============================================================================
# Omnibus:                      698.886   Durbin-Watson:                   2.079
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            83277.825
# Skew:                           1.727   Prob(JB):                         0.00
# Kurtosis:                      43.733   Cond. No.                         92.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 30.87
# Expected Return: SBUX   -0.017176
# dtype: float64
# /home/nickkats1/Quant-I-Guess/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for: TSLA, 1       0.024443
# 2       0.002901
# 3       0.003466
# 4       0.043229
# 5       0.015674
#           ...
# 1192    0.039779
# 1193   -0.043813
# 1194    0.040176
# 1195    0.006381
# 1196    0.003407
# Name: TSLA, Length: 1196, dtype: float64
# Excess Returns: 1       0.015243
# 2      -0.006299
# 3      -0.005734
# 4       0.034029
# 5       0.006474
#           ...
# 1192    0.030579
# 1193   -0.053013
# 1194    0.030976
# 1195   -0.002819
# 1196   -0.005793
# Name: TSLA, Length: 1196, dtype: float64
# Market Returns: ^GSPC,1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64;----- Market Excess Returns: 1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64
# Alpha Value: 0.0002
# Beta Value: 2.0352
# Adjusted Beta: 1.690126
# Firm Specific Risk: 0.0010
# Systematic Risk: 0.0005
# Total Risk: 0.0014900910120299665
# Error Term: 1       0.017030
# 2      -0.015067
# 3       0.007783
# 4       0.040283
# 5       0.002354
#           ...
# 1192    0.045357
# 1193   -0.033835
# 1194    0.027948
# 1195    0.000801
# 1196   -0.005135
# Length: 1196, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   TSLA   R-squared:                       0.324
# Model:                            OLS   Adj. R-squared:                  0.323
# Method:                 Least Squares   F-statistic:                     571.9
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):          1.37e-103
# Time:                        18:53:09   Log-Likelihood:                 2429.3
# No. Observations:                1196   AIC:                            -4855.
# Df Residuals:                    1194   BIC:                            -4844.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.001      0.235      0.814      -0.002       0.002
# ^GSPC          2.0352      0.085     23.915      0.000       1.868       2.202
# ==============================================================================
# Omnibus:                      139.390   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              831.535
# Skew:                           0.346   Prob(JB):                    2.72e-181
# Kurtosis:                       7.026   Cond. No.                         92.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 32.39
# Expected Return: TSLA    0.165115
# dtype: float64
# /home/nickkats1/Quant-I-Guess/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for: GOOGL, 1       0.003431
# 2       0.022951
# 3      -0.009132
# 4      -0.012237
# 5       0.009440
#           ...
# 1192   -0.017961
# 1193   -0.005463
# 1194    0.003051
# 1195   -0.010100
# 1196   -0.003893
# Name: GOOGL, Length: 1196, dtype: float64
# Excess Returns: 1      -0.005769
# 2       0.013751
# 3      -0.018332
# 4      -0.021437
# 5       0.000240
#           ...
# 1192   -0.027161
# 1193   -0.014663
# 1194   -0.006149
# 1195   -0.019300
# 1196   -0.013093
# Name: GOOGL, Length: 1196, dtype: float64
# Market Returns: ^GSPC,1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64;----- Market Excess Returns: 1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64
# Alpha Value: 0.0004
# Beta Value: 1.2640
# Adjusted Beta: 1.175969
# Firm Specific Risk: 0.0002
# Systematic Risk: 0.0002
# Total Risk: 0.0003852221911010348
# Error Term: 1      -0.001400
# 2       0.011565
# 3      -0.006678
# 4      -0.014294
# 5       0.000941
#           ...
# 1192   -0.014724
# 1193    0.000508
# 1194   -0.004769
# 1195   -0.013792
# 1196   -0.009424
# Length: 1196, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  GOOGL   R-squared:                       0.483
# Model:                            OLS   Adj. R-squared:                  0.483
# Method:                 Least Squares   F-statistic:                     1116.
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):          2.37e-173
# Time:                        18:53:09   Log-Likelihood:                 3399.0
# No. Observations:                1196   AIC:                            -6794.
# Df Residuals:                    1194   BIC:                            -6784.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0004      0.000      0.883      0.377      -0.000       0.001
# ^GSPC          1.2640      0.038     33.412      0.000       1.190       1.338
# ==============================================================================
# Omnibus:                      187.865   Durbin-Watson:                   1.933
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2773.871
# Skew:                           0.132   Prob(JB):                         0.00
# Kurtosis:                      10.456   Cond. No.                         92.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 48.32
# Expected Return: GOOGL    0.245315
# dtype: float64
# /home/nickkats1/Quant-I-Guess/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for: SPY, 1       0.003890
# 2       0.008591
# 3      -0.001908
# 4       0.001427
# 5       0.005081
#           ...
# 1192   -0.003182
# 1193   -0.004614
# 1194    0.005729
# 1195    0.002810
# 1196    0.003767
# Name: SPY, Length: 1196, dtype: float64
# Excess Returns: 1      -0.005310
# 2      -0.000609
# 3      -0.011108
# 4      -0.007773
# 5      -0.004119
#           ...
# 1192   -0.012382
# 1193   -0.013814
# 1194   -0.003471
# 1195   -0.006390
# 1196   -0.005433
# Name: SPY, Length: 1196, dtype: float64
# Market Returns: ^GSPC,1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64;----- Market Excess Returns: 1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64
# Alpha Value: 0.0001
# Beta Value: 1.0078
# Adjusted Beta: 1.005214
# Firm Specific Risk: 0.0000
# Systematic Risk: 0.0001
# Total Risk: 0.00011866288046691302
# Error Term: 1       0.000274
# 2      -0.000252
# 3       0.000285
# 4       0.000023
# 5      -0.001460
#           ...
# 1192   -0.000364
# 1193    0.000383
# 1194   -0.000271
# 1195    0.000103
# 1196   -0.000408
# Length: 1196, dtype: float64
# /home/nickkats1/Quant-I-Guess/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    SPY   R-squared:                       0.997
# Model:                            OLS   Adj. R-squared:                  0.997
# Method:                 Least Squares   F-statistic:                 4.417e+05
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):               0.00
# Time:                        18:53:09   Log-Likelihood:                 7246.1
# No. Observations:                1196   AIC:                        -1.449e+04
# Df Residuals:                    1194   BIC:                        -1.448e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.169e-05   1.64e-05      3.154      0.002    1.95e-05    8.38e-05
# ^GSPC          1.0078      0.002    664.574      0.000       1.005       1.011
# ==============================================================================
# Omnibus:                      503.450   Durbin-Watson:                   2.911
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           571231.032
# Skew:                           0.073   Prob(JB):                         0.00
# Kurtosis:                     110.065   Cond. No.                         92.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 99.73
# Expected Return: SPY    0.149327
# dtype: float64
# Returns for: QQQ, 1       0.004413
# 2       0.010079
# 3       0.000895
# 4       0.000032
# 5       0.002461
#           ...
# 1192   -0.003511
# 1193   -0.004311
# 1194    0.004111
# 1195    0.004631
# 1196    0.002739
# Name: QQQ, Length: 1196, dtype: float64
# Excess Returns: 1      -0.004787
# 2       0.000879
# 3      -0.008305
# 4      -0.009168
# 5      -0.006739
#           ...
# 1192   -0.012711
# 1193   -0.013511
# 1194   -0.005089
# 1195   -0.004569
# 1196   -0.006461
# Name: QQQ, Length: 1196, dtype: float64
# Market Returns: ^GSPC,1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64;----- Market Excess Returns: 1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64
# Alpha Value: -0.0000
# Beta Value: 1.2645
# Adjusted Beta: 1.176306
# Firm Specific Risk: 0.0000
# Systematic Risk: 0.0002
# Total Risk: 0.00020733792773370877
# Error Term: 1      -0.000042
# 2      -0.000933
# 3       0.003729
# 4      -0.001647
# 5      -0.005664
#           ...
# 1192    0.000106
# 1193    0.002040
# 1194   -0.003334
# 1195    0.001316
# 1196   -0.002416
# Length: 1196, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    QQQ   R-squared:                       0.898
# Model:                            OLS   Adj. R-squared:                  0.898
# Method:                 Least Squares   F-statistic:                 1.057e+04
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):               0.00
# Time:                        18:53:09   Log-Likelihood:                 4742.6
# No. Observations:                1196   AIC:                            -9481.
# Df Residuals:                    1194   BIC:                            -9471.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.734e-05      0.000     -0.130      0.896      -0.000       0.000
# ^GSPC          1.2645      0.012    102.794      0.000       1.240       1.289
# ==============================================================================
# Omnibus:                       42.346   Durbin-Watson:                   2.043
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              105.138
# Skew:                          -0.114   Prob(JB):                     1.48e-23
# Kurtosis:                       4.435   Cond. No.                         92.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 89.85
# Expected Return: QQQ    0.157832
# dtype: float64
# /home/nickkats1/Quant-I-Guess/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for: VTI, 1       0.001673
# 2       0.006327
# 3      -0.004174
# 4       0.002691
# 5       0.004593
#           ...
# 1192   -0.003657
# 1193   -0.005353
# 1194    0.006274
# 1195    0.002535
# 1196    0.003271
# Name: VTI, Length: 1196, dtype: float64
# Excess Returns: 1      -0.007527
# 2      -0.002873
# 3      -0.013374
# 4      -0.006509
# 5      -0.004607
#           ...
# 1192   -0.012857
# 1193   -0.014553
# 1194   -0.002926
# 1195   -0.006665
# 1196   -0.005929
# Name: VTI, Length: 1196, dtype: float64
# Market Returns: ^GSPC,1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64;----- Market Excess Returns: 1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64
# Alpha Value: -0.0000
# Beta Value: 1.0263
# Adjusted Beta: 1.017548
# Firm Specific Risk: 0.0000
# Systematic Risk: 0.0001
# Total Risk: 0.00012402982546540287
# Error Term: 1      -0.001951
# 2      -0.002619
# 3      -0.001883
# 4       0.001320
# 5      -0.002009
#           ...
# 1192   -0.000730
# 1193   -0.000207
# 1194    0.000223
# 1195   -0.000165
# 1196   -0.000922
# ...
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.068
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):              0.302
# Time:                        18:53:12   Log-Likelihood:                 7902.0
# No. Observations:                1196   AIC:                        -1.580e+04
# Df Residuals:                    1194   BIC:                        -1.579e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.362e-07   9.47e-06      0.046      0.963   -1.81e-05     1.9e-05
# ^GSPC         -0.0009      0.001     -1.033      0.302      -0.003       0.001
# ==============================================================================
# Omnibus:                      229.934   Durbin-Watson:                   2.893
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5578.939
# Skew:                           0.115   Prob(JB):                         0.00
# Kurtosis:                      13.578   Cond. No.                         92.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 0.09
# Expected Return: USDC-USD   -0.00003
# dtype: float64
# /home/nickkats1/Quant-I-Guess/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for: STETH-USD, 1       0.039297
# 2       0.188442
# 3      -0.008528
# 4      -0.000356
# 5       0.014450
#           ...
# 1192   -0.003584
# 1193   -0.069114
# 1194    0.043298
# 1195    0.046762
# 1196   -0.018236
# Name: STETH-USD, Length: 1196, dtype: float64
# Excess Returns: 1       0.030097
# 2       0.179242
# 3      -0.017728
# 4      -0.009556
# 5       0.005250
#           ...
# 1192   -0.012784
# 1193   -0.078314
# 1194    0.034098
# 1195    0.037562
# 1196   -0.027436
# Name: STETH-USD, Length: 1196, dtype: float64
# Market Returns: ^GSPC,1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64;----- Market Excess Returns: 1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64
# Alpha Value: 0.0020
# Beta Value: 1.6443
# Adjusted Beta: 1.429517
# Firm Specific Risk: 0.0022
# Systematic Risk: 0.0003
# Total Risk: 0.0025155219614177785
# Error Term: 1       0.031510
# 2       0.172128
# 3      -0.006837
# 4      -0.004533
# 5       0.001892
#           ...
# 1192   -0.000875
# 1193   -0.062849
# 1194    0.031622
# 1195    0.040457
# 1196   -0.026934
# Length: 1196, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              STETH-USD   R-squared:                       0.125
# Model:                            OLS   Adj. R-squared:                  0.124
# Method:                 Least Squares   F-statistic:                     170.9
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):           1.33e-36
# Time:                        18:53:13   Log-Likelihood:                 1962.2
# No. Observations:                1196   AIC:                            -3920.
# Df Residuals:                    1194   BIC:                            -3910.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0020      0.001      1.450      0.147      -0.001       0.005
# ^GSPC          1.6443      0.126     13.074      0.000       1.398       1.891
# ==============================================================================
# Omnibus:                      261.264   Durbin-Watson:                   2.072
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2884.524
# Skew:                           0.674   Prob(JB):                         0.00
# Kurtosis:                      10.488   Cond. No.                         92.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 12.52
# Expected Return: STETH-USD    0.508414
# dtype: float64
# /home/nickkats1/Quant-I-Guess/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for: TRX-USD, 1       0.115915
# 2       0.066253
# 3      -0.062373
# 4      -0.026905
# 5      -0.004157
#           ...
# 1192    0.006626
# 1193   -0.018856
# 1194    0.019899
# 1195   -0.004218
# 1196   -0.010089
# Name: TRX-USD, Length: 1196, dtype: float64
# Excess Returns: 1       0.106715
# 2       0.057053
# 3      -0.071573
# 4      -0.036105
# 5      -0.013357
#           ...
# 1192   -0.002574
# 1193   -0.028056
# 1194    0.010699
# 1195   -0.013418
# 1196   -0.019289
# Name: TRX-USD, Length: 1196, dtype: float64
# Market Returns: ^GSPC,1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64;----- Market Excess Returns: 1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64
# Alpha Value: 0.0030
# Beta Value: 0.9809
# Adjusted Beta: 0.987299
# Firm Specific Risk: 0.0029
# Systematic Risk: 0.0001
# Total Risk: 0.003010290390483665
# Error Term: 1       0.109479
# 2       0.054730
# 3      -0.063154
# 4      -0.031187
# 5      -0.013439
#           ...
# 1192    0.006453
# 1193   -0.016909
# 1194    0.011144
# 1195   -0.009770
# 1196   -0.017068
# Length: 1196, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                TRX-USD   R-squared:                       0.037
# Model:                            OLS   Adj. R-squared:                  0.036
# Method:                 Least Squares   F-statistic:                     46.19
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):           1.69e-11
# Time:                        18:53:13   Log-Likelihood:                 1797.5
# No. Observations:                1196   AIC:                            -3591.
# Df Residuals:                    1194   BIC:                            -3581.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0030      0.002      1.901      0.057   -9.44e-05       0.006
# ^GSPC          0.9809      0.144      6.796      0.000       0.698       1.264
# ==============================================================================
# Omnibus:                     1402.292   Durbin-Watson:                   2.262
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           396644.202
# Skew:                           5.460   Prob(JB):                         0.00
# Kurtosis:                      91.545   Cond. No.                         92.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 3.72
# Expected Return: TRX-USD    0.728973
# dtype: float64
# /home/nickkats1/Quant-I-Guess/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for: LINK-USD, 1       0.068703
# 2       0.090962
# 3      -0.067883
# 4      -0.043968
# 5       0.001507
#           ...
# 1192    0.003528
# 1193   -0.069942
# 1194    0.048609
# 1195    0.031459
# 1196   -0.019304
# Name: LINK-USD, Length: 1196, dtype: float64
# Excess Returns: 1       0.059503
# 2       0.081762
# 3      -0.077083
# 4      -0.053168
# 5      -0.007693
#           ...
# 1192   -0.005672
# 1193   -0.079142
# 1194    0.039409
# 1195    0.022259
# 1196   -0.028504
# Name: LINK-USD, Length: 1196, dtype: float64
# Market Returns: ^GSPC,1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64;----- Market Excess Returns: 1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64
# Alpha Value: 0.0015
# Beta Value: 1.8804
# Adjusted Beta: 1.586910
# Firm Specific Risk: 0.0035
# Systematic Risk: 0.0004
# Total Risk: 0.0038701274533421617
# Error Term: 1       0.060590
# 2       0.073097
# 3      -0.065158
# 4      -0.047953
# 5      -0.012063
#           ...
# 1192    0.007418
# 1193   -0.061986
# 1194    0.036048
# 1195    0.025040
# 1196   -0.028460
# Length: 1196, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LINK-USD   R-squared:                       0.106
# Model:                            OLS   Adj. R-squared:                  0.106
# Method:                 Least Squares   F-statistic:                     142.2
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):           4.63e-31
# Time:                        18:53:13   Log-Likelihood:                 1691.8
# No. Observations:                1196   AIC:                            -3380.
# Df Residuals:                    1194   BIC:                            -3369.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0015      0.002      0.859      0.391      -0.002       0.005
# ^GSPC          1.8804      0.158     11.926      0.000       1.571       2.190
# ==============================================================================
# Omnibus:                      173.571   Durbin-Watson:                   2.081
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1288.061
# Skew:                           0.431   Prob(JB):                    2.00e-280
# Kurtosis:                       8.011   Cond. No.                         92.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 10.64
# Expected Return: LINK-USD    0.153478
# dtype: float64
# /home/nickkats1/Quant-I-Guess/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for: ^GSPC, 1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64
# Excess Returns: 1      -0.005663
# 2      -0.000477
# 3      -0.011427
# 4      -0.007858
# 5      -0.002761
#           ...
# 1192   -0.012047
# 1193   -0.014209
# 1194   -0.003298
# 1195   -0.006564
# 1196   -0.005109
# Name: ^GSPC, Length: 1196, dtype: float64
# Market Returns: ^GSPC,1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64;----- Market Excess Returns: 1       0.003537
# 2       0.008723
# 3      -0.002227
# 4       0.001342
# 5       0.006439
#           ...
# 1192   -0.002847
# 1193   -0.005009
# 1194    0.005902
# 1195    0.002636
# 1196    0.004091
# Name: ^GSPC, Length: 1196, dtype: float64
# Alpha Value: -0.0000
# Beta Value: 1.0000
# Adjusted Beta: 1.000000
# Firm Specific Risk: 0.0000
# Systematic Risk: 0.0001
# Total Risk: 0.00011651315438035887
# Error Term: 1      -1.301043e-18
# 2      -3.469447e-18
# 3       1.301043e-18
# 4      -2.168404e-19
# 5      -1.734723e-18
#             ...
# 1192    1.734723e-18
# 1193    3.469447e-18
# 1194   -1.734723e-18
# 1195   -8.673617e-19
# 1196   -8.673617e-19
# Length: 1196, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  ^GSPC   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 6.010e+33
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):               0.00
# Time:                        18:53:13   Log-Likelihood:                 45994.
# No. Observations:                1196   AIC:                        -9.198e+04
# Df Residuals:                    1194   BIC:                        -9.197e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5.014e-19   1.39e-19     -3.597      0.000   -7.75e-19   -2.28e-19
# ^GSPC          1.0000   1.29e-17   7.75e+16      0.000       1.000       1.000
# ==============================================================================
# Omnibus:                      203.863   Durbin-Watson:                   2.051
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2644.661
# Skew:                          -0.345   Prob(JB):                         0.00
# Kurtosis:                      10.252   Cond. No.                         92.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 100.00
# Expected Return: ^GSPC    0.133507
# dtype: float64
# /home/nickkats1/Quant-I-Guess/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
