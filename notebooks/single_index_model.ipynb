# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import statsmodels.api as sm
from src.config import load_config
import numpy as np
from pypfopt import expected_returns
import os
import yfinance as yf

class Sim:
    def __init__(self,config):
        self.config = config


    def fetch_yfinance_data(self):
        """ Fetch Data from yfinance API """
        
        # all prices include SP&500
        all_prices = yf.download(tickers=self.config['combined_assets'],start=self.config['start_date'],end=self.config['end_date'])['Close']
        all_prices = all_prices.dropna()
        all_prices.drop_duplicates(inplace=True)

        return all_prices


    def single_index_model(self,output_dir="images/sim/"):

        #tickers to turn data into correct frame
        all_prices = self.fetch_yfinance_data()

        sp500_ticker = self.config['sp500_ticker']
        tickers = self.config['combined_assets']
        risk_free_rate = self.config['risk_free_rate']

        # sp500 data
        sp500_data = all_prices[sp500_ticker]
        # Market Returns(sp500) and Market Excess Returns
        market_returns = sp500_data.pct_change().dropna()
        market_excess_returns = sp500_data.pct_change().dropna()

        #market index risk is of the sp500(variance(sp500))
        market_index_risk = np.var(market_returns)
        print(f'Market Index Risk: {market_index_risk}')




        # alphas, betas, total risk, covariance, market index risk,firm specific risk,product of betas
        alphas = {}
        betas = {}
        error_terms = {}
        adjusted_betas = {}
        firm_specific_risks = {}
        systematic_risks = {}
        total_risks = {}
        risk_premiums = {}
        Expected_Returns = {}
    







        for ticker in tickers:
            asset_data = all_prices[ticker]
            returns = asset_data.pct_change().dropna()
            Excess_Returns = asset_data.pct_change().dropna() - risk_free_rate
            print(f'Returns for: {ticker}, {returns}')
            print(f'Excess Returns: {Excess_Returns}')
            print(f'Market Returns: {sp500_ticker},{market_returns};----- Market Excess Returns: {market_excess_returns}')



            model = sm.OLS(exog=sm.add_constant(market_returns),endog=returns).fit()
            

            # alpha, beta, error-term (e), firm-specific risk(variance(e)), market risk(variance of sp500 in this case).
            # risk premium: E(R) - Rf
            alpha = model.params.const
            beta = model.params.iloc[1]
            residuals = model.resid
            




            # adjusted beta: 2/3 * beta + 1/3 * 1
            adj_beta = (2/3) * beta + (1/3) * 1


            # Systematic risk is (Beta**2) * Market Index Risk (defined above)
            systematic_risk = (beta**2) * market_index_risk

            #  firm-specific risk is the variance of the "Unanticipated surpises" (the variance of the residuals for the asset)
            firm_specific_risk = np.var(residuals)

            # total risk = systematic Risk + Firm Specific Risk
            total_risk = systematic_risk + firm_specific_risk






            alphas[ticker] = alpha
            betas[ticker] = beta
            error_terms[ticker] = residuals
            adjusted_betas[ticker] = adj_beta
            systematic_risks[ticker] = systematic_risk
            firm_specific_risks[ticker] = firm_specific_risk
            total_risks[ticker] = total_risk

            print(f'Alpha Value: {alpha:.4f}')
            print(f'Beta Value: {beta:.4f}')
            print(f'Adjusted Beta: {adj_beta:4f}')
            print(f'Firm Specific Risk: {firm_specific_risk:.4f}')
            print(f'Systematic Risk: {systematic_risk:.4f}')
            print(f'Total Risk: {total_risk}')
            print(f'Error Term: {residuals}')

            


        

            # E(r) -> The Expected Return using pyportfolio & Risk Premiun = E(r) - rf 
            Expected_Return = expected_returns.mean_historical_return(asset_data)
            risk_premium = Expected_Return - risk_free_rate

            Expected_Returns[ticker] = Expected_Return
            risk_premiums[ticker] = risk_premium
            

            
            # for the individual betas and alphas

            print(f'ANOVA Table: {model.summary()}')
            print(f'R2 Score: {model.rsquared*100:.2f}')
            print(f'Expected Return: {Expected_Return}')


            



            ## plots
            plt.figure(figsize=(12,6))
            sns.scatterplot(x=market_returns, y=returns, label=ticker)
            sns.lineplot(x=market_returns, y=model.fittedvalues, color='red', label='Security Market Line')
                
            plt.title(f'Single Index Model for {ticker}')
            plt.xlabel('Market Excess Return')
            plt.ylabel(f'{ticker} Excess Return')
            plt.legend()
            os.makedirs(output_dir, exist_ok=True)
            plt.savefig(os.path.join(output_dir, f"single_index_model_{ticker}.png"))
            plt.show()



if __name__ == "__main__":
    config = load_config()
    sim_config = Sim(config)
    sim_config.fetch_yfinance_data()
    sim_config.single_index_model()
# Out:
# /tmp/ipykernel_144172/3286688630.py:20: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   all_prices = yf.download(tickers=self.config['combined_assets'],start=self.config['start_date'],end=self.config['end_date'])['Close']
# [*********************100%***********************]  31 of 31 completed
# /tmp/ipykernel_144172/3286688630.py:20: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   all_prices = yf.download(tickers=self.config['combined_assets'],start=self.config['start_date'],end=self.config['end_date'])['Close']
# [*********************100%***********************]  31 of 31 completed
# /home/nickkats1/Quant-I-Guess/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Market Index Risk: 0.00011643582435465575
# Returns for: AAPL, Date
# 2020-12-24    0.007712
# 2020-12-28    0.035766
# 2020-12-29   -0.013315
# 2020-12-30   -0.008527
# 2020-12-31   -0.007702
#                 ...
# 2025-10-08    0.006160
# 2025-10-09   -0.015578
# 2025-10-10   -0.034522
# 2025-10-13    0.009744
# 2025-10-14    0.000444
# Name: AAPL, Length: 1206, dtype: float64
# Excess Returns: Date
# 2020-12-24   -0.001488
# 2020-12-28    0.026566
# 2020-12-29   -0.022515
# 2020-12-30   -0.017727
# 2020-12-31   -0.016902
#                 ...
# 2025-10-08   -0.003040
# 2025-10-09   -0.024778
# 2025-10-10   -0.043722
# 2025-10-13    0.000544
# 2025-10-14   -0.008756
# Name: AAPL, Length: 1206, dtype: float64
# Market Returns: ^GSPC,Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-10-08    0.005828
# 2025-10-09   -0.002756
# 2025-10-10   -0.027112
# 2025-10-13    0.015599
# 2025-10-14   -0.001564
# Name: ^GSPC, Length: 1206, dtype: float64;----- Market Excess Returns: Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-10-08    0.005828
# 2025-10-09   -0.002756
# 2025-10-10   -0.027112
# 2025-10-13    0.015599
# 2025-10-14   -0.001564
# Name: ^GSPC, Length: 1206, dtype: float64
# Alpha Value: 0.0000
# Beta Value: 1.2576
# Adjusted Beta: 1.171720
# Firm Specific Risk: 0.0001
# Systematic Risk: 0.0002
# Total Risk: 0.00031709762280080053
# Error Term: Date
# 2020-12-24    0.003243
# 2020-12-28    0.024775
# 2020-12-29   -0.010536
# 2020-12-30   -0.010235
# 2020-12-31   -0.015821
#                 ...
# 2025-10-08   -0.001190
# 2025-10-09   -0.012134
# 2025-10-10   -0.000449
# 2025-10-13   -0.009894
# 2025-10-14    0.002390
# Length: 1206, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   AAPL   R-squared:                       0.581
# Model:                            OLS   Adj. R-squared:                  0.580
# Method:                 Least Squares   F-statistic:                     1668.
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):          1.69e-229
# Time:                        19:28:58   Log-Likelihood:                 3670.8
# No. Observations:                1206   AIC:                            -7338.
# Df Residuals:                    1204   BIC:                            -7327.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.158e-05      0.000      0.065      0.948      -0.001       0.001
# ^GSPC          1.2576      0.031     40.836      0.000       1.197       1.318
# ==============================================================================
# Omnibus:                      111.426   Durbin-Watson:                   1.819
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              642.730
# Skew:                           0.171   Prob(JB):                    2.71e-140
# Kurtosis:                       6.560   Cond. No.                         92.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 58.07
# Expected Return: AAPL    0.148724
# dtype: float64
# /home/nickkats1/Quant-I-Guess/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for: MSFT, Date
# 2020-12-24    0.007827
# 2020-12-28    0.009921
# 2020-12-29   -0.003601
# 2020-12-30   -0.011020
# 2020-12-31    0.003338
#                 ...
# 2025-10-08    0.001660
# 2025-10-09   -0.004668
# 2025-10-10   -0.021899
# 2025-10-13    0.006047
# 2025-10-14   -0.000934
# Name: MSFT, Length: 1206, dtype: float64
# Excess Returns: Date
# 2020-12-24   -0.001373
# 2020-12-28    0.000721
# 2020-12-29   -0.012801
# 2020-12-30   -0.020220
# 2020-12-31   -0.005862
#                 ...
# 2025-10-08   -0.007540
# 2025-10-09   -0.013868
# 2025-10-10   -0.031099
# 2025-10-13   -0.003153
# 2025-10-14   -0.010134
# Name: MSFT, Length: 1206, dtype: float64
# Market Returns: ^GSPC,Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-10-08    0.005828
# 2025-10-09   -0.002756
# 2025-10-10   -0.027112
# 2025-10-13    0.015599
# 2025-10-14   -0.001564
# Name: ^GSPC, Length: 1206, dtype: float64;----- Market Excess Returns: Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-10-08    0.005828
# 2025-10-09   -0.002756
# 2025-10-10   -0.027112
# 2025-10-13    0.015599
# 2025-10-14   -0.001564
# Name: ^GSPC, Length: 1206, dtype: float64
# Alpha Value: 0.0002
# Beta Value: 1.1629
# Adjusted Beta: 1.108622
# Firm Specific Risk: 0.0001
# Systematic Risk: 0.0002
# Total Risk: 0.0002667589701829869
# Error Term: Date
# 2020-12-24    0.003484
# 2020-12-28   -0.000453
# 2020-12-29   -0.001240
# 2020-12-30   -0.012810
# 2020-12-31   -0.004380
#                 ...
# 2025-10-08   -0.005347
# 2025-10-09   -0.001694
# 2025-10-10    0.009400
# 2025-10-13   -0.012323
# 2025-10-14    0.000655
# Length: 1206, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   MSFT   R-squared:                       0.590
# Model:                            OLS   Adj. R-squared:                  0.590
# Method:                 Least Squares   F-statistic:                     1735.
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):          1.50e-235
# Time:                        19:28:58   Log-Likelihood:                 3789.0
# No. Observations:                1206   AIC:                            -7574.
# Df Residuals:                    1204   BIC:                            -7564.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.000      0.763      0.445      -0.000       0.001
# ^GSPC          1.1629      0.028     41.651      0.000       1.108       1.218
# ==============================================================================
# Omnibus:                      220.772   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3659.662
# Skew:                           0.311   Prob(JB):                         0.00
# Kurtosis:                      11.511   Cond. No.                         92.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 59.03
# Expected Return: MSFT    0.202517
# dtype: float64
# Returns for: TGT, Date
# 2020-12-24    0.001601
# 2020-12-28    0.006850
# 2020-12-29   -0.007653
# 2020-12-30   -0.006627
# 2020-12-31    0.015240
#                 ...
# 2025-10-08    0.012434
# 2025-10-09   -0.014162
# 2025-10-10   -0.040067
# 2025-10-13    0.021162
# 2025-10-14    0.018548
# Name: TGT, Length: 1206, dtype: float64
# Excess Returns: Date
# 2020-12-24   -0.007599
# 2020-12-28   -0.002350
# 2020-12-29   -0.016853
# 2020-12-30   -0.015827
# 2020-12-31    0.006040
#                 ...
# 2025-10-08    0.003234
# 2025-10-09   -0.023362
# 2025-10-10   -0.049267
# 2025-10-13    0.011962
# 2025-10-14    0.009348
# Name: TGT, Length: 1206, dtype: float64
# Market Returns: ^GSPC,Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-10-08    0.005828
# 2025-10-09   -0.002756
# 2025-10-10   -0.027112
# 2025-10-13    0.015599
# 2025-10-14   -0.001564
# Name: ^GSPC, Length: 1206, dtype: float64;----- Market Excess Returns: Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-10-08    0.005828
# 2025-10-09   -0.002756
# 2025-10-10   -0.027112
# 2025-10-13    0.015599
# 2025-10-14   -0.001564
# Name: ^GSPC, Length: 1206, dtype: float64
# Alpha Value: -0.0007
# Beta Value: 0.9863
# Adjusted Beta: 0.990878
# Firm Specific Risk: 0.0004
# Systematic Risk: 0.0001
# Total Risk: 0.0004952264130681848
# Error Term: Date
# 2020-12-24   -0.001148
# 2020-12-28   -0.001014
# 2020-12-29   -0.004717
# 2020-12-30   -0.007211
# 2020-12-31    0.009629
#                 ...
# 2025-10-08    0.007426
# 2025-10-09   -0.010705
# 2025-10-10   -0.012587
# 2025-10-13    0.006516
# 2025-10-14    0.020831
# Length: 1206, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    TGT   R-squared:                       0.229
# Model:                            OLS   Adj. R-squared:                  0.228
# Method:                 Least Squares   F-statistic:                     357.1
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):           6.03e-70
# Time:                        19:28:58   Log-Likelihood:                 3034.5
# No. Observations:                1206   AIC:                            -6065.
# Df Residuals:                    1204   BIC:                            -6055.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0007      0.001     -1.311      0.190      -0.002       0.000
# ^GSPC          0.9863      0.052     18.896      0.000       0.884       1.089
# ==============================================================================
# Omnibus:                      542.250   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            50830.196
# Skew:                          -1.128   Prob(JB):                         0.00
# Kurtosis:                      34.725   Cond. No.                         92.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 22.87
# Expected Return: TGT   -0.108528
# dtype: float64
# /home/nickkats1/Quant-I-Guess/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for: GM, Date
# 2020-12-24   -0.020495
# 2020-12-28    0.001924
# 2020-12-29   -0.002160
# 2020-12-30    0.006495
# 2020-12-31   -0.004780
#                 ...
# 2025-10-08   -0.015019
# 2025-10-09   -0.008511
# 2025-10-10   -0.010193
# 2025-10-13    0.004878
# 2025-10-14    0.027508
# Name: GM, Length: 1206, dtype: float64
# Excess Returns: Date
# 2020-12-24   -0.029695
# 2020-12-28   -0.007276
# 2020-12-29   -0.011360
# 2020-12-30   -0.002705
# 2020-12-31   -0.013980
#                 ...
# 2025-10-08   -0.024219
# 2025-10-09   -0.017711
# 2025-10-10   -0.019393
# 2025-10-13   -0.004322
# 2025-10-14    0.018308
# Name: GM, Length: 1206, dtype: float64
# Market Returns: ^GSPC,Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-10-08    0.005828
# 2025-10-09   -0.002756
# 2025-10-10   -0.027112
# 2025-10-13    0.015599
# 2025-10-14   -0.001564
# Name: ^GSPC, Length: 1206, dtype: float64;----- Market Excess Returns: Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-10-08    0.005828
# 2025-10-09   -0.002756
# 2025-10-10   -0.027112
# 2025-10-13    0.015599
# 2025-10-14   -0.001564
# Name: ^GSPC, Length: 1206, dtype: float64
# Alpha Value: -0.0001
# Beta Value: 1.1851
# Adjusted Beta: 1.123369
# Firm Specific Risk: 0.0004
# Systematic Risk: 0.0002
# Total Risk: 0.0005443213850530118
# Error Term: Date
# 2020-12-24   -0.024585
# 2020-12-28   -0.008312
# 2020-12-29    0.000580
# 2020-12-30    0.005006
# 2020-12-31   -0.012310
#                 ...
# 2025-10-08   -0.021825
# 2025-10-09   -0.005145
# 2025-10-10    0.022036
# 2025-10-13   -0.013507
# 2025-10-14    0.029462
# Length: 1206, dtype: float64
# /home/nickkats1/Quant-I-Guess/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     GM   R-squared:                       0.300
# Model:                            OLS   Adj. R-squared:                  0.300
# Method:                 Least Squares   F-statistic:                     517.0
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):           1.66e-95
# Time:                        19:28:58   Log-Likelihood:                 3036.3
# No. Observations:                1206   AIC:                            -6069.
# Df Residuals:                    1204   BIC:                            -6058.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0001      0.001     -0.179      0.858      -0.001       0.001
# ^GSPC          1.1851      0.052     22.738      0.000       1.083       1.287
# ==============================================================================
# Omnibus:                      111.250   Durbin-Watson:                   2.173
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              622.913
# Skew:                           0.191   Prob(JB):                    5.45e-136
# Kurtosis:                       6.500   Cond. No.                         92.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 30.04
# Expected Return: GM    0.071648
# dtype: float64
# Returns for: F, Date
# 2020-12-24   -0.014461
# 2020-12-28    0.003386
# 2020-12-29   -0.007874
# 2020-12-30    0.004535
# 2020-12-31   -0.007901
#                 ...
# 2025-10-08   -0.015101
# 2025-10-09   -0.020443
# 2025-10-10   -0.007826
# 2025-10-13    0.011394
# 2025-10-14    0.009532
# Name: F, Length: 1206, dtype: float64
# Excess Returns: Date
# 2020-12-24   -0.023661
# 2020-12-28   -0.005814
# 2020-12-29   -0.017074
# 2020-12-30   -0.004665
# 2020-12-31   -0.017101
#                 ...
# 2025-10-08   -0.024301
# 2025-10-09   -0.029643
# 2025-10-10   -0.017026
# 2025-10-13    0.002194
# 2025-10-14    0.000332
# Name: F, Length: 1206, dtype: float64
# Market Returns: ^GSPC,Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-10-08    0.005828
# 2025-10-09   -0.002756
# 2025-10-10   -0.027112
# 2025-10-13    0.015599
# 2025-10-14   -0.001564
# Name: ^GSPC, Length: 1206, dtype: float64;----- Market Excess Returns: Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-10-08    0.005828
# 2025-10-09   -0.002756
# 2025-10-10   -0.027112
# 2025-10-13    0.015599
# 2025-10-14   -0.001564
# Name: ^GSPC, Length: 1206, dtype: float64
# Alpha Value: 0.0001
# Beta Value: 1.2366
# Adjusted Beta: 1.157711
# Firm Specific Risk: 0.0004
# Systematic Risk: 0.0002
# Total Risk: 0.0006226389728317633
# Error Term: Date
# 2020-12-24   -0.018907
# 2020-12-28   -0.007473
# 2020-12-29   -0.005193
# 2020-12-30    0.002803
# 2020-12-31   -0.015936
#                 ...
# 2025-10-08   -0.022380
# 2025-10-09   -0.017109
# 2025-10-10    0.025626
# 2025-10-13   -0.007968
# 2025-10-14    0.011393
# Length: 1206, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      F   R-squared:                       0.286
# Model:                            OLS   Adj. R-squared:                  0.285
# Method:                 Least Squares   F-statistic:                     482.1
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):           3.79e-90
# Time:                        19:28:59   Log-Likelihood:                 2942.9
# No. Observations:                1206   AIC:                            -5882.
# Df Residuals:                    1204   BIC:                            -5872.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       7.307e-05      0.001      0.120      0.904      -0.001       0.001
# ^GSPC          1.2366      0.056     21.958      0.000       1.126       1.347
# ==============================================================================
# Omnibus:                      242.553   Durbin-Watson:                   2.059
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3225.214
# Skew:                          -0.521   Prob(JB):                         0.00
# Kurtosis:                      10.943   Cond. No.                         92.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 28.59
# Expected Return: F    0.115659
# dtype: float64
# /home/nickkats1/Quant-I-Guess/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for: WMT, Date
# 2020-12-24    0.001955
# 2020-12-28    0.011986
# 2020-12-29   -0.006335
# 2020-12-30   -0.000831
# 2020-12-31   -0.000208
#                 ...
# 2025-10-08   -0.003293
# 2025-10-09   -0.010982
# 2025-10-10    0.000688
# 2025-10-13    0.002749
# 2025-10-14    0.049843
# Name: WMT, Length: 1206, dtype: float64
# Excess Returns: Date
# 2020-12-24   -0
Length: 1206, dtype: float64
# Excess Returns: Date
# 2020-12-24   -0.009690
# 2020-12-28    0.013641
# 2020-12-29    0.003163
# 2020-12-30   -0.005981
# 2020-12-31    0.000331
#                 ...
# 2025-10-08   -0.024577
# 2025-10-09   -0.012448
# 2025-10-10   -0.025745
# 2025-10-13    0.010810
# 2025-10-14    0.004795
# Name: SBUX, Length: 1206, dtype: float64
# Market Returns: ^GSPC,Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-10-08    0.005828
# 2025-10-09   -0.002756
# 2025-10-10   -0.027112
# 2025-10-13    0.015599
# 2025-10-14   -0.001564
# Name: ^GSPC, Length: 1206, dtype: float64;----- Market Excess Returns: Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-10-08    0.005828
# 2025-10-09   -0.002756
# 2025-10-10   -0.027112
# 2025-10-13    0.015599
# 2025-10-14   -0.001564
# Name: ^GSPC, Length: 1206, dtype: float64
# Alpha Value: -0.0005
# Beta Value: 1.0075
# Adjusted Beta: 1.005012
# Firm Specific Risk: 0.0003
# Systematic Risk: 0.0001
# Total Risk: 0.00038654384510596767
# Error Term: Date
# 2020-12-24   -0.003591
# 2020-12-28    0.014515
# 2020-12-29    0.015069
# 2020-12-30    0.002329
# 2020-12-31    0.003506
#                 ...
# 2025-10-08   -0.020787
# 2025-10-09   -0.000010
# 2025-10-10    0.011232
# 2025-10-13    0.004756
# 2025-10-14    0.016033
# Length: 1206, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   SBUX   R-squared:                       0.306
# Model:                            OLS   Adj. R-squared:                  0.305
# Method:                 Least Squares   F-statistic:                     530.3
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):           1.60e-97
# Time:                        19:29:00   Log-Likelihood:                 3247.4
# No. Observations:                1206   AIC:                            -6491.
# Df Residuals:                    1204   BIC:                            -6481.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0005      0.000     -0.977      0.329      -0.001       0.000
# ^GSPC          1.0075      0.044     23.028      0.000       0.922       1.093
# ==============================================================================
# Omnibus:                      692.208   Durbin-Watson:                   2.074
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            81130.847
# Skew:                           1.680   Prob(JB):                         0.00
# Kurtosis:                      43.041   Cond. No.                         92.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 30.58
# Expected Return: SBUX   -0.025549
# dtype: float64
# /home/nickkats1/Quant-I-Guess/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for: TSLA, Date
# 2020-12-24    0.024443
# 2020-12-28    0.002901
# 2020-12-29    0.003466
# 2020-12-30    0.043229
# 2020-12-31    0.015674
#                 ...
# 2025-10-08    0.012930
# 2025-10-09   -0.007180
# 2025-10-10   -0.050627
# 2025-10-13    0.054197
# 2025-10-14   -0.015279
# Name: TSLA, Length: 1206, dtype: float64
# Excess Returns: Date
# 2020-12-24    0.015243
# 2020-12-28   -0.006299
# 2020-12-29   -0.005734
# 2020-12-30    0.034029
# 2020-12-31    0.006474
#                 ...
# 2025-10-08    0.003730
# 2025-10-09   -0.016380
# 2025-10-10   -0.059827
# 2025-10-13    0.044997
# 2025-10-14   -0.024479
# Name: TSLA, Length: 1206, dtype: float64
# Market Returns: ^GSPC,Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-10-08    0.005828
# 2025-10-09   -0.002756
# 2025-10-10   -0.027112
# 2025-10-13    0.015599
# 2025-10-14   -0.001564
# Name: ^GSPC, Length: 1206, dtype: float64;----- Market Excess Returns: Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-10-08    0.005828
# 2025-10-09   -0.002756
# 2025-10-10   -0.027112
# 2025-10-13    0.015599
# 2025-10-14   -0.001564
# Name: ^GSPC, Length: 1206, dtype: float64
# Alpha Value: 0.0002
# Beta Value: 2.0397
# Adjusted Beta: 1.693140
# Firm Specific Risk: 0.0010
# Systematic Risk: 0.0005
# Total Risk: 0.001490088487075869
# Error Term: Date
# 2020-12-24    0.017031
# 2020-12-28   -0.015089
# 2020-12-29    0.007810
# 2020-12-30    0.040294
# 2020-12-31    0.002342
#                 ...
# 2025-10-08    0.000845
# 2025-10-09   -0.001759
# 2025-10-10    0.004474
# 2025-10-13    0.022182
# 2025-10-14   -0.012287
# Length: 1206, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   TSLA   R-squared:                       0.325
# Model:                            OLS   Adj. R-squared:                  0.325
# Method:                 Least Squares   F-statistic:                     580.0
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):          6.44e-105
# Time:                        19:29:00   Log-Likelihood:                 2450.7
# No. Observations:                1206   AIC:                            -4897.
# Df Residuals:                    1204   BIC:                            -4887.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.001      0.217      0.828      -0.002       0.002
# ^GSPC          2.0397      0.085     24.082      0.000       1.874       2.206
# ==============================================================================
# Omnibus:                      139.621   Durbin-Watson:                   1.973
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              829.356
# Skew:                           0.343   Prob(JB):                    8.09e-181
# Kurtosis:                       7.004   Cond. No.                         92.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 32.51
# Expected Return: TSLA    0.155057
# dtype: float64
# /home/nickkats1/Quant-I-Guess/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for: GOOGL, Date
# 2020-12-24    0.003431
# 2020-12-28    0.022951
# 2020-12-29   -0.009132
# 2020-12-30   -0.012237
# 2020-12-31    0.009440
#                 ...
# 2025-10-08   -0.004639
# 2025-10-09   -0.012632
# 2025-10-10   -0.020536
# 2025-10-13    0.032041
# 2025-10-14    0.005325
# Name: GOOGL, Length: 1206, dtype: float64
# Excess Returns: Date
# 2020-12-24   -0.005769
# 2020-12-28    0.013751
# 2020-12-29   -0.018332
# 2020-12-30   -0.021437
# 2020-12-31    0.000240
#                 ...
# 2025-10-08   -0.013839
# 2025-10-09   -0.021832
# 2025-10-10   -0.029736
# 2025-10-13    0.022841
# 2025-10-14   -0.003875
# Name: GOOGL, Length: 1206, dtype: float64
# Market Returns: ^GSPC,Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-10-08    0.005828
# 2025-10-09   -0.002756
# 2025-10-10   -0.027112
# 2025-10-13    0.015599
# 2025-10-14   -0.001564
# Name: ^GSPC, Length: 1206, dtype: float64;----- Market Excess Returns: Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-10-08    0.005828
# 2025-10-09   -0.002756
# 2025-10-10   -0.027112
# 2025-10-13    0.015599
# 2025-10-14   -0.001564
# Name: ^GSPC, Length: 1206, dtype: float64
# Alpha Value: 0.0004
# Beta Value: 1.2631
# Adjusted Beta: 1.175405
# Firm Specific Risk: 0.0002
# Systematic Risk: 0.0002
# Total Risk: 0.000384092236147747
# Error Term: Date
# 2020-12-24   -0.001410
# 2020-12-28    0.011559
# 2020-12-29   -0.006693
# 2020-12-30   -0.014306
# 2020-12-31    0.000933
#                 ...
# 2025-10-08   -0.012374
# 2025-10-09   -0.009525
# 2025-10-10    0.013335
# 2025-10-13    0.011964
# 2025-10-14    0.006927
# Length: 1206, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  GOOGL   R-squared:                       0.484
# Model:                            OLS   Adj. R-squared:                  0.483
# Method:                 Least Squares   F-statistic:                     1128.
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):          5.14e-175
# Time:                        19:29:00   Log-Likelihood:                 3429.7
# No. Observations:                1206   AIC:                            -6855.
# Df Residuals:                    1204   BIC:                            -6845.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0004      0.000      0.920      0.358      -0.000       0.001
# ^GSPC          1.2631      0.038     33.582      0.000       1.189       1.337
# ==============================================================================
# Omnibus:                      189.197   Durbin-Watson:                   1.932
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2795.351
# Skew:                           0.130   Prob(JB):                         0.00
# Kurtosis:                      10.454   Cond. No.                         92.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 48.37
# Expected Return: GOOGL    0.245553
# dtype: float64
# /home/nickkats1/Quant-I-Guess/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for: SPY, Date
# 2020-12-24    0.003890
# 2020-12-28    0.008591
# 2020-12-29   -0.001908
# 2020-12-30    0.001427
# 2020-12-31    0.005081
#                 ...
# 2025-10-08    0.005963
# 2025-10-09   -0.002897
# 2025-10-10   -0.027028
# 2025-10-13    0.015344
# 2025-10-14   -0.001222
# Name: SPY, Length: 1206, dtype: float64
# Excess Returns: Date
# 2020-12-24   -0.005310
# 2020-12-28   -0.000609
# 2020-12-29   -0.011108
# 2020-12-30   -0.007773
# 2020-12-31   -0.004119
#                 ...
# 2025-10-08   -0.003237
# 2025-10-09   -0.012097
# 2025-10-10   -0.036228
# 2025-10-13    0.006144
# 2025-10-14   -0.010422
# Name: SPY, Length: 1206, dtype: float64
# Market Returns: ^GSPC,Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-10-08    0.005828
# 2025-10-09   -0.002756
# 2025-10-10   -0.027112
# 2025-10-13    0.015599
# 2025-10-14   -0.001564
# Name: ^GSPC, Length: 1206, dtype: float64;----- Market Excess Returns: Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-10-08    0.005828
# 2025-10-09   -0.002756
# 2025-10-10   -0.027112
# 2025-10-13    0.015599
# 2025-10-14   -0.001564
# Name: ^GSPC, Length: 1206, dtype: float64
# Alpha Value: 0.0001
# Beta Value: 1.0077
# Adjusted Beta: 1.005148
# Firm Specific Risk: 0.0000
# Systematic Risk: 0.0001
# Total Risk: 0.00011855892487182561
# Error Term: Date
# 2020-12-24    0.000275
# 2020-12-28   -0.000251
# 2020-12-29    0.000285
# 2020-12-30    0.000023
# 2020-12-31   -0.001460
#                 ...
# 2025-10-08    0.000038
# 2025-10-09   -0.000172
# 2025-10-10    0.000241
# 2025-10-13   -0.000427
# 2025-10-14    0.000303
# Length: 1206, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    SPY   R-squared:                       0.997
# Model:                            OLS   Adj. R-squared:                  0.997
# Method:                 Least Squares   F-statistic:                 4.479e+05
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):               0.00
# Time:                        19:29:00   Log-Likelihood:                 7310.7
# No. Observations:                1206   AIC:                        -1.462e+04
# Df Residuals:                    1204   BIC:                        -1.461e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       5.191e-05   1.63e-05      3.191      0.001       2e-05    8.38e-05
# ^GSPC          1.0077      0.002    669.286      0.000       1.005       1.011
# ==============================================================================
# Omnibus:                      508.399   Durbin-Watson:                   2.912
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           585325.860
# Skew:                           0.079   Prob(JB):                         0.00
# Kurtosis:                     110.927   Cond. No.                         92.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 99.73
# Expected Return: SPY    0.146575
# dtype: float64
# /home/nickkats1/Quant-I-Guess/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for
# Length: 1206, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              STETH-USD   R-squared:                       0.129
# Model:                            OLS   Adj. R-squared:                  0.128
# Method:                 Least Squares   F-statistic:                     178.3
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):           5.02e-38
# Time:                        19:29:05   Log-Likelihood:                 1979.2
# No. Observations:                1206   AIC:                            -3954.
# Df Residuals:                    1204   BIC:                            -3944.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0020      0.001      1.449      0.148      -0.001       0.005
# ^GSPC          1.6720      0.125     13.352      0.000       1.426       1.918
# ==============================================================================
# Omnibus:                      262.429   Durbin-Watson:                   2.077
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2875.980
# Skew:                           0.673   Prob(JB):                         0.00
# Kurtosis:                      10.445   Cond. No.                         92.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 12.90
# Expected Return: STETH-USD    0.502086
# dtype: float64
# /home/nickkats1/Quant-I-Guess/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for: TRX-USD, Date
# 2020-12-24    0.115915
# 2020-12-28    0.066253
# 2020-12-29   -0.062373
# 2020-12-30   -0.026905
# 2020-12-31   -0.004157
#                 ...
# 2025-10-08    0.012032
# 2025-10-09   -0.016059
# 2025-10-10   -0.046617
# 2025-10-13    0.006084
# 2025-10-14   -0.018384
# Name: TRX-USD, Length: 1206, dtype: float64
# Excess Returns: Date
# 2020-12-24    0.106715
# 2020-12-28    0.057053
# 2020-12-29   -0.071573
# 2020-12-30   -0.036105
# 2020-12-31   -0.013357
#                 ...
# 2025-10-08    0.002832
# 2025-10-09   -0.025259
# 2025-10-10   -0.055817
# 2025-10-13   -0.003116
# 2025-10-14   -0.027584
# Name: TRX-USD, Length: 1206, dtype: float64
# Market Returns: ^GSPC,Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-10-08    0.005828
# 2025-10-09   -0.002756
# 2025-10-10   -0.027112
# 2025-10-13    0.015599
# 2025-10-14   -0.001564
# Name: ^GSPC, Length: 1206, dtype: float64;----- Market Excess Returns: Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-10-08    0.005828
# 2025-10-09   -0.002756
# 2025-10-10   -0.027112
# 2025-10-13    0.015599
# 2025-10-14   -0.001564
# Name: ^GSPC, Length: 1206, dtype: float64
# Alpha Value: 0.0029
# Beta Value: 0.9862
# Adjusted Beta: 0.990793
# Firm Specific Risk: 0.0029
# Systematic Risk: 0.0001
# Total Risk: 0.0029892470222264043
# Error Term: Date
# 2020-12-24    0.109524
# 2020-12-28    0.054748
# 2020-12-29   -0.063079
# 2020-12-30   -0.031131
# 2020-12-31   -0.013410
#                 ...
# 2025-10-08    0.003382
# 2025-10-09   -0.016245
# 2025-10-10   -0.022783
# 2025-10-13   -0.012202
# 2025-10-14   -0.019745
# Length: 1206, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                TRX-USD   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.037
# Method:                 Least Squares   F-statistic:                     47.41
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):           9.26e-12
# Time:                        19:29:05   Log-Likelihood:                 1817.1
# No. Observations:                1206   AIC:                            -3630.
# Df Residuals:                    1204   BIC:                            -3620.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0029      0.002      1.876      0.061      -0.000       0.006
# ^GSPC          0.9862      0.143      6.885      0.000       0.705       1.267
# ==============================================================================
# Omnibus:                     1417.021   Durbin-Watson:                   2.262
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           405938.847
# Skew:                           5.480   Prob(JB):                         0.00
# Kurtosis:                      92.209   Cond. No.                         92.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 3.79
# Expected Return: TRX-USD    0.70278
# dtype: float64
# /home/nickkats1/Quant-I-Guess/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for: LINK-USD, Date
# 2020-12-24    0.068703
# 2020-12-28    0.090962
# 2020-12-29   -0.067883
# 2020-12-30   -0.043968
# 2020-12-31    0.001507
#                 ...
# 2025-10-08    0.034989
# 2025-10-09   -0.026896
# 2025-10-10   -0.211588
# 2025-10-13    0.144639
# 2025-10-14   -0.037833
# Name: LINK-USD, Length: 1206, dtype: float64
# Excess Returns: Date
# 2020-12-24    0.059503
# 2020-12-28    0.081762
# 2020-12-29   -0.077083
# 2020-12-30   -0.053168
# 2020-12-31   -0.007693
#                 ...
# 2025-10-08    0.025789
# 2025-10-09   -0.036096
# 2025-10-10   -0.220788
# 2025-10-13    0.135439
# 2025-10-14   -0.047033
# Name: LINK-USD, Length: 1206, dtype: float64
# Market Returns: ^GSPC,Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-10-08    0.005828
# 2025-10-09   -0.002756
# 2025-10-10   -0.027112
# 2025-10-13    0.015599
# 2025-10-14   -0.001564
# Name: ^GSPC, Length: 1206, dtype: float64;----- Market Excess Returns: Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-10-08    0.005828
# 2025-10-09   -0.002756
# 2025-10-10   -0.027112
# 2025-10-13    0.015599
# 2025-10-14   -0.001564
# Name: ^GSPC, Length: 1206, dtype: float64
# Alpha Value: 0.0014
# Beta Value: 1.9300
# Adjusted Beta: 1.619999
# Firm Specific Risk: 0.0035
# Systematic Risk: 0.0004
# Total Risk: 0.0039033371576601274
# Error Term: Date
# 2020-12-24    0.060500
# 2020-12-28    0.072750
# 2020-12-29   -0.064962
# 2020-12-30   -0.047934
# 2020-12-31   -0.012297
#                 ...
# 2025-10-08    0.022364
# 2025-10-09   -0.022955
# 2025-10-10   -0.160639
# 2025-10-13    0.113156
# 2025-10-14   -0.036191
# Length: 1206, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               LINK-USD   R-squared:                       0.111
# Model:                            OLS   Adj. R-squared:                  0.110
# Method:                 Least Squares   F-statistic:                     150.5
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):           1.10e-32
# Time:                        19:29:05   Log-Likelihood:                 1704.0
# No. Observations:                1206   AIC:                            -3404.
# Df Residuals:                    1204   BIC:                            -3394.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0014      0.002      0.810      0.418      -0.002       0.005
# ^GSPC          1.9300      0.157     12.268      0.000       1.621       2.239
# ==============================================================================
# Omnibus:                      172.322   Durbin-Watson:                   2.091
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1267.240
# Skew:                           0.422   Prob(JB):                    6.64e-276
# Kurtosis:                       7.951   Cond. No.                         92.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 11.11
# Expected Return: LINK-USD    0.126005
# dtype: float64
# /home/nickkats1/Quant-I-Guess/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
# Returns for: ^GSPC, Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-10-08    0.005828
# 2025-10-09   -0.002756
# 2025-10-10   -0.027112
# 2025-10-13    0.015599
# 2025-10-14   -0.001564
# Name: ^GSPC, Length: 1206, dtype: float64
# Excess Returns: Date
# 2020-12-24   -0.005663
# 2020-12-28   -0.000477
# 2020-12-29   -0.011427
# 2020-12-30   -0.007858
# 2020-12-31   -0.002761
#                 ...
# 2025-10-08   -0.003372
# 2025-10-09   -0.011956
# 2025-10-10   -0.036312
# 2025-10-13    0.006399
# 2025-10-14   -0.010764
# Name: ^GSPC, Length: 1206, dtype: float64
# Market Returns: ^GSPC,Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-10-08    0.005828
# 2025-10-09   -0.002756
# 2025-10-10   -0.027112
# 2025-10-13    0.015599
# 2025-10-14   -0.001564
# Name: ^GSPC, Length: 1206, dtype: float64;----- Market Excess Returns: Date
# 2020-12-24    0.003537
# 2020-12-28    0.008723
# 2020-12-29   -0.002227
# 2020-12-30    0.001342
# 2020-12-31    0.006439
#                 ...
# 2025-10-08    0.005828
# 2025-10-09   -0.002756
# 2025-10-10   -0.027112
# 2025-10-13    0.015599
# 2025-10-14   -0.001564
# Name: ^GSPC, Length: 1206, dtype: float64
# Alpha Value: -0.0000
# Beta Value: 1.0000
# Adjusted Beta: 1.000000
# Firm Specific Risk: 0.0000
# Systematic Risk: 0.0001
# Total Risk: 0.00011643582435465567
# Error Term: Date
# 2020-12-24    1.301043e-18
# 2020-12-28    3.469447e-18
# 2020-12-29   -8.673617e-19
# 2020-12-30    6.505213e-19
# 2020-12-31    1.734723e-18
#                   ...
# 2025-10-08    1.734723e-18
# 2025-10-09   -8.673617e-19
# 2025-10-10   -1.040834e-17
# 2025-10-13    5.204170e-18
# 2025-10-14   -2.168404e-19
# Length: 1206, dtype: float64
# ANOVA Table:                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  ^GSPC   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 9.826e+33
# Date:                Thu, 16 Oct 2025   Prob (F-statistic):               0.00
# Time:                        19:29:06   Log-Likelihood:                 46671.
# No. Observations:                1206   AIC:                        -9.334e+04
# Df Residuals:                    1204   BIC:                        -9.333e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.423e-19   1.09e-19     -1.306      0.192   -3.56e-19    7.15e-20
# ^GSPC          1.0000   1.01e-17   9.91e+16      0.000       1.000       1.000
# ==============================================================================
# Omnibus:                      142.318   Durbin-Watson:                   2.057
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1209.918
# Skew:                          -0.150   Prob(JB):                    1.86e-263
# Kurtosis:                       7.898   Cond. No.                         92.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# R2 Score: 100.00
# Expected Return: ^GSPC    0.130764
# dtype: float64
# /home/nickkats1/Quant-I-Guess/venv/lib/python3.12/site-packages/pypfopt/expected_returns.py:137: RuntimeWarning: prices are not in a dataframe
#   warnings.warn("prices are not in a dataframe", RuntimeWarning)
